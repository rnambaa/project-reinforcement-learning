# %%
import pandas as pd
from utils import *
import seaborn as sns

# set plot size larger
sns.set(rc={'figure.figsize':(11.7,8.27)})
# set seaborn style
sns.set_style("whitegrid")

# %%
train_data_melted = preprocess_data('data/train.xlsx', 'data/validate.xlsx')
train_data_melted
# Out:
#             Date  Hour  Price
# 0     2007-01-01     1  24.31
# 1096  2007-01-01     2  24.31
# 2192  2007-01-01     3  21.71
# 3288  2007-01-01     4   8.42
# 4384  2007-01-01     5   0.01
# ...          ...   ...    ...
# 21919 2009-12-31    20  36.00
# 23015 2009-12-31    21  29.00
# 24111 2009-12-31    22  24.82
# 25207 2009-12-31    23  31.28
# 26303 2009-12-31    24  31.00
#
# [26304 rows x 3 columns]

# %%
# plot x axis date y axis price
sns.lineplot(x='Date', y='Price', data=train_data_melted)
# Out:
# <Axes: xlabel='Date', ylabel='Price'>

# %%
# plot the data
sns.lineplot(data=train_data_melted, x='Hour', y='Price')
# Out:
# <Axes: xlabel='Hour', ylabel='Price'>

# %%
# plot the price per day of the week, extracted from the date column
# step 1 extract the day of the week from the date column
train_data_melted['Day'] = train_data_melted['Date'].dt.day_name()
sns.lineplot(data=train_data_melted, x='Day', y='Price')
# Out:
# <Axes: xlabel='Day', ylabel='Price'>
